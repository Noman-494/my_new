# %%
import pandas as pd

# %%
whr_pd=pd.read_csv("whr.csv")

# %%
iris_pd=pd.read_csv("iris.csv")

# %%
data_pd = pd.read_csv("data.csv", encoding='ISO-8859-1')

# %% [markdown]
# ### Question 1

# %%
iris_pd     ## I have imported pandas and created file into dataframe for working
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_pd.head()   ## First Five Row  i used head function of pandas which by default represent five rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_pd.pivot_table(values="petal_length",index="species",aggfunc="mean")  ## average for average I used pivottable mean
# Out:
#                  petal_length
# species
# Iris-setosa             1.464
# Iris-versicolor         4.260
# Iris-virginica          5.552

# %%
iris_pd["petal_length"]>5  #I have used boolen series and
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147     True
# 148     True
# 149     True
# Name: petal_length, Length: 150, dtype: bool

# %%
iris_pd[iris_pd["petal_length"]>5]  # Rows containing data more than 5 it can be used Index to extract the desired data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 83            6.0          2.7           5.1          1.6  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 102           7.1          3.0           5.9          2.1   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 104           6.5          3.0           5.8          2.2   Iris-virginica
# 105           7.6          3.0           6.6          2.1   Iris-virginica
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# 110           6.5          3.2           5.1          2.0   Iris-virginica
# ...

# %%
##Display the descriptive statistics (mean, standard deviation, etc.) for the "sepal length" and
#"sepal width" columns in this new Data.

# %%
iris_pd.pivot_table(values=["sepal_width","sepal_length"],index="species",aggfunc="mean")
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             5.006        3.418
# Iris-versicolor         5.936        2.770
# Iris-virginica          6.588        2.974

# %%
iris_pd.pivot_table(values=["sepal_width","sepal_length"],index="species",aggfunc="sum")
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             250.3        170.9
# Iris-versicolor         296.8        138.5
# Iris-virginica          329.4        148.7

# %%
iris_pd.pivot_table(values=["sepal_width","sepal_length"],index="species",aggfunc="std")
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa          0.352490     0.381024
# Iris-versicolor      0.516171     0.313798
# Iris-virginica       0.635880     0.322497

# %%
iris_pd.pivot_table(values=["sepal_width","sepal_length"],index="species",aggfunc="median")
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa               5.0          3.4
# Iris-versicolor           5.9          2.8
# Iris-virginica            6.5          3.0

# %% [markdown]
# ## question 2

# %%
## I have imported file in pandas as dataframe and I also imported file in normal python through read csv

# %%
data_pd.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
import csv  ## through normal python

# %%
with open("data.csv") as f:
    data=list(csv.reader(f))
    header=data[0]
    data=data[1:]

# %%
header
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
data_pd.info()  ## understanding the file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
## customer ID column has blank data means we dont know the customer so replace blank id with word No customer ID

# %%
data_pd["CustomerID"].isnull().sum()
# Out:
# 135080

# %%
data_pd.loc[data_pd["CustomerID"].isnull(),"CustomerID"]="No customer ID"  #repalced with No customer Id

# %% [markdown]
# ##Find the total number of orders placed by each customer.## each row is one order so take value count of customer id means it count the each id

# %%
data_pd["CustomerID"].value_counts().sort_values(ascending=False)
# Out:
# CustomerID
# No customer ID    135080
# 17841.0             7983
# 14911.0             5903
# 14096.0             5128
# 12748.0             4642
#                    ...
# 14576.0                1
# 12503.0                1
# 13391.0                1
# 16738.0                1
# 15562.0                1
# Name: count, Length: 4373, dtype: int64

# %% [markdown]
# ##Asuming that negative quantiy in data is sales return we dont clean it or remove minus and if we remove the minus result will change

# %%
data_pd["value"]=(data_pd["Quantity"]*data_pd["UnitPrice"])

# %%
data_pd.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country  value
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom  20.34

# %% [markdown]
# ##Top Five customer with average order value

# %%
data_pd.pivot_table(values="value",index="CustomerID",aggfunc="mean").sort_values(by="value",ascending=False).head()
# Out:
#                   value
# CustomerID
# 15195.0     3861.000000
# 13135.0     3096.000000
# 17846.0     2033.100000
# 16532.0     1687.200000
# 15749.0     1435.726667

# %%
## function to determine order value  using above logic we created customer average order value

# %%
def order_value(data):
    average_order=data_pd.pivot_table(values="value",index="CustomerID",aggfunc="mean")
    return average_order

# %%
order_value(data_pd)   ## zero value is appearing beacasue customer purchased it and returned it so zero value
# Out:
#                 value
# CustomerID
# 12346.0      0.000000
# 12347.0     23.681319
# 12348.0     57.975484
# 12349.0     24.076027
# 12350.0     19.670588
# ...               ...
# 18280.0     18.060000
# 18281.0     11.545714
# 18282.0     13.584615
# 18283.0      2.771005
# 18287.0     26.246857
#
# [4372 rows x 1 columns]

# %% [markdown]
# ## Question #3

# %%
whr_pd.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
## column can inserted by simply using file name and entering the column name in [] but it will be blank first

# %%
whr_pd["Happiness Score Category"]=""

# %%
whr_pd.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption Happiness Score Category
# 0                      0.393

# %%
## we have to create boolen series for every condtion 
#a) Low (Score < 5)
#b) Medium (5 <= Score < 7)
#c) High (Score >= 7)
# After this we update our columns on the basis of the boolen series

# %%
whr_pd["Score"]<5   ## condition 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151     True
# 152     True
# 153     True
# 154     True
# 155     True
# Name: Score, Length: 156, dtype: bool

# %%
whr_pd.loc[whr_pd["Score"]<5,"Happiness Score Category"]="Low"       ## updated

# %%
(whr_pd["Score"]>=5) & (whr_pd["Score"]<7)   ##Condition 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Score, Length: 156, dtype: bool

# %%
whr_pd.loc[(whr_pd["Score"]>=5) & (whr_pd["Score"]<7),"Happiness Score Category"]="Medium"  ## updated

# %%
whr_pd["Score"]>=7   #condition Three
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Score, Length: 156, dtype: bool

# %%
whr_pd.loc[whr_pd["Score"]>=7,"Happiness Score Category"]="High"  ## updated

# %%
whr_pd.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Happiness Score Category
# 0                      0.393                     High
# ...

# %%
whr_pd["Country or region"]=="Finland"   ## to gain experience to create function
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Country or region, Length: 156, dtype: bool

# %%
whr_pd.loc[whr_pd["Country or region"]=="Finland","Score"]
# Out:
# 0    7.769
# Name: Score, dtype: float64

# %%
## so by using above logic we can create function by generalizing it

# %%
def country_score(country):
    score=whr_pd.loc[whr_pd["Country or region"]==country,"Score"]
    return score

# %%
country_score("Netherlands")
# Out:
# 4    7.488
# Name: Score, dtype: float64

# %%
country_score("Denmark")
# Out:
# 1    7.6
# Name: Score, dtype: float64

# %%
### we can now see score of the any country by just input of the name

# %%
### top five countries with their categories

# %%
whr_pd.loc[:,["Country or region","Score","Happiness Score Category"]].sort_values(by="Score",ascending=False).head()
# Out:
#   Country or region  Score Happiness Score Category
# 0           Finland  7.769                     High
# 1           Denmark  7.600                     High
# 2            Norway  7.554                     High
# 3           Iceland  7.494                     High
# 4       Netherlands  7.488                     High
