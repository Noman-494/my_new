# %%
import pandas as pd

# %%
date_w("1970-1980")
# Out:
# 1975

# %%
import func

# %%
header,moma=func.read_csv("works.csv")

# %%
type(moma)

# %%
moma_df=pd.read_csv("works.csv")

# %%
type(moma_df)

# %%
moma_df.ndimim

# %%
moma_df.shape

# %%
for row in moma[:5]:
    nat=row[2]
    gen=row[-3]
    nat.strip("(").strip(")")
    gen.replace("(","").replace(")","")
    print(nat,gen)

# %%
moma_df.head()

# %%
c=moma_df["Nationality"].str.strip("(").str.replace(")","")

# %%
moma_df["Nationality"]=c

# %%
moma_df

# %%
moma_df["Nationality"]=moma_df["Nationality"].str.strip("(").str.replace(")","")

# %%
moma_df.head()

# %%
for row in moma:
    nat=row[2].title()
    if nat=="":
        nat="Nationality Unknown"
        row[2]=nat

# %%
moma[-5:]

# %%
import pandas as pd

# %%
import func

# %%
header,mamo_data=func.read_csv("works.csv")

# %%
mamo_data[0]
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  '(American)',
#  '(1947)',
#  '(2013)',
#  '(Female)',
#  '1986',
#  'Prints & Illustrated Books']

# %%
type(mamo_data)
# Out:
# list

# %%
mamo_pd=pd.read_csv("works.csv")

# %%
type(mamo_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
mamo_pd.shape
# Out:
# (16725, 8)

# %%
mamo_pd.ndim
# Out:
# 2

# %%
for i in mamo_data:
    nationality=i[-3].strip("(").strip(")")
    gender= i[-6].strip("(").strip(")")
    print(nationality,gender)
# Out:
# Female American
# Male Spanish
# Male French
# Male French
# Male French
# Male American
# Male French
# Male American
# Female South African
# Male Canadian
# Male French
# Male American
# Male Czech
# Male American
# Male American
# Male American
# Male Belgian
# Male American
# Male American
# Male Spanish
# Male American
# Female Russian
# Male American
# Male French
# Male French
# Male French
# Female British
# Male French
# Male French
# Male German
# Male Belgian
#
# Male American
# Male American
# Male American
# Male Swiss
# Male
# Male American
# Male American
# Male Polish
# Male British
# Male American
# Male American
# Male Belgian
# Male American
# Male Japanese
# Male American
# Male American
# Male Spanish
# Male American
# Male French
# Male American
# Male American
# Male American
# Male American
# Male French
# Female American
# Male American
# Male French
# Male American
# Female American
# Male Portuguese
# Female American
# Male American
# Male Austrian
# ...

# %%
mamo_data[:5]
# Out:
# [['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   '(American)',
#   '(1947)',
#   '(2013)',
#   '(Female)',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   '(Spanish)',
#   '(1916)',
#   '(2007)',
#   '(Male)',
#   '1978',
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   '(French)',
#   '(1870)',
#   '(1943)',
#   '(Male)',
#   '1889-1911',
#   'Prints & Illustrated Books'],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN',
#   'Aristide Maillol',
#   '(French)',
#   '(1861)',
#   '(1944)',
#   '(Male)',
#   '1927-1940',
#   'Prints & Illustrated Books'],
#  ['97 rue du Bac',
#   'Eugène Atget',
#   '(French)',
#   '(1857)',
#   '(1927)',
#   '(Male)',
#   '1903',
#   'Photography']]

# %%
for i in mamo_data:
    nationality=i[-3].strip("(").strip(")")
    gender= i[-6].strip("(").strip(")")
    i[-3]=nationality
    i[-6]=gender

# %%
mamo_data[:5]
# Out:
# [['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   'American',
#   '(1947)',
#   '(2013)',
#   'Female',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   'Spanish',
#   '(1916)',
#   '(2007)',
#   'Male',
#   '1978',
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   'French',
#   '(1870)',
#   '(1943)',
#   'Male',
#   '1889-1911',
#   'Prints & Illustrated Books'],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN',
#   'Aristide Maillol',
#   'French',
#   '(1861)',
#   '(1944)',
#   'Male',
#   '1927-1940',
#   'Prints & Illustrated Books'],
#  ['97 rue du Bac',
#   'Eugène Atget',
#   'French',
#   '(1857)',
#   '(1927)',
#   'Male',
#   '1903',
#   'Photography']]

# %%
column_data=[]
for i in updated_list:
    nationality=i[-6]
    if nationality not in column_data:
        column_data.append(nationality)

# %%
column_data=[]
for i in mamo_data:
    nationality=i[-6]
    if nationality not in column_data:
        column_data.append(nationality)

# %%
column_data

# %%
column_data

# %%
mamo_data[:5]

# %%
mamo_pd
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
mamo_pd.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate    Gender       Date  \
# 0  (American)    (1947)  (2013)  (Female)       1986
# 1   (Spanish)    (1916)  (2007)    (Male)       1978
# 2    (French)    (1870)  (1943)    (Male)  1889-1911
# 3    (French)    (1861)  (1944)    (Male)  1927-1940
# 4    (French)    (1857)  (1927)    (Male)       1903
#
#                    Department
# 0  Prints & Illustrated Books
# 1  Prints & Illustrated Books
# 2  Prints & Illustrated Books
# 3  Prints & Illustrated Books
# 4                 Photography

# %%
mamo_pd.tail()
# Out:
#                                                    Title         Artist  \
# 16720                                   Oval with Points    Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile    Juan Baixas
# 16722                                        The Catboat  Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...        Unknown
# 16724                      Plate (page 11) from The Dive      Alex Katz
#
#       Nationality BeginDate EndDate  Gender       Date  \
# 16720   (British)    (1898)  (1986)  (Male)  1968-1969
# 16721   (Chilean)    (1942)     NaN  (Male)       1975
# 16722  (American)    (1882)  (1967)  (Male)       1922
# 16723          ()       NaN     NaN      ()       1931
# 16724  (American)    (1927)     NaN  (Male)       2011
#
#                        Department
# 16720        Painting & Sculpture
# 16721       Architecture & Design
# 16722  Prints & Illustrated Books
# 16723  Prints & Illustrated Books
# ...

# %%
mamo_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16725 entries, 0 to 16724
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        16724 non-null  object
#  1   Artist       16725 non-null  object
#  2   Nationality  16725 non-null  object
#  3   BeginDate    15786 non-null  object
#  4   EndDate      10474 non-null  object
#  5   Gender       16725 non-null  object
#  6   Date         16725 non-null  object
#  7   Department   16725 non-null  object
# dtypes: object(8)
# memory usage: 1.0+ MB

# %%
mamo_pd["Nationality"]
# Out:
# 0        (American)
# 1         (Spanish)
# 2          (French)
# 3          (French)
# 4          (French)
#             ...
# 16720     (British)
# 16721     (Chilean)
# 16722    (American)
# 16723            ()
# 16724    (American)
# Name: Nationality, Length: 16725, dtype: object

# %%
mamo_pd["Nationality"].shape
# Out:
# (16725,)

# %%
mamo_pd["Nationality"].str.strip("(").str.strip(")")
# Out:
# 0        American
# 1         Spanish
# 2          French
# 3          French
# 4          French
#            ...
# 16720     British
# 16721     Chilean
# 16722    American
# 16723
# 16724    American
# Name: Nationality, Length: 16725, dtype: object

# %%
mamo_pd["Nationality"]=mamo_pd["Nationality"].str.strip("(").str.strip(")")

# %%
mamo_pd
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
mamo_pd["Gender"]=mamo_pd["Gender"].str.strip("(").str.strip(")")

# %%
mamo_pd
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
mamo_ex=mamo_data.copy()

# %%
for i in mamo_ex:
    nat=i[-6].title()
    if nat=="":
        nat="Unknow Nationality"
        i[-6]=nat

# %%
print(mamo_ex[-10:])
# Out:
# [['Untitled (Edward and Clara Smith Steichen On Their Honeymoon)', 'Edward Steichen', 'American', '(1879)', '(1973)', 'Male', '1903', 'Photography'], ['Untitled (Heat/Gun)', 'Marco Breuer', 'German', '(1966)', '', 'Male', '1999', 'Photography'], ['Plate (folio 7) from EXPLORATIONS', 'Henri Goetz', 'French', '(1909)', '(1989)', 'Male', '1947', 'Prints & Illustrated Books'], ['High Peak', 'Matthew Rackham Barnes', 'American', '(1880)', '(1951)', 'Male', '1936', 'Painting & Sculpture'], ['Picasso Sculpture (paper, skull)', 'Brassaï (Gyula Halász)', 'French', '(1899)', '(1984)', 'Male', '1943', 'Photography'], ['Oval with Points', 'Henry Moore', 'British', '(1898)', '(1986)', 'Male', '1968-1969', 'Painting & Sculpture'], ['Cementerio de la Ciudad Abierta, Ritoque, Chile', 'Juan Baixas', 'Chilean', '(1942)', '', 'Male', '1975', 'Architecture & Design'], ['The Catboat', 'Edward Hopper', 'American', '(1882)', '(1967)', 'Male', '1922', 'Prints & Illustrated Books'], ["Dognat' i peregnat' v t
# ...

# %%
for i in mamo_ex:
    gen=[-3]
    if gen=="":
        gen="Unkomwn Gender"
        i[-3]= gen

# %%
for row in mamo_ex:
    gen = row[-3].title()
    if gen == "":
        gen = "Gender Unknown"
    row[-3] = gen

# %%
mamo_ex[-5:]
# Out:
# [['Oval with Points',
#   'Henry Moore',
#   'British',
#   '(1898)',
#   '(1986)',
#   'Male',
#   '1968-1969',
#   'Painting & Sculpture'],
#  ['Cementerio de la Ciudad Abierta, Ritoque, Chile',
#   'Juan Baixas',
#   'Chilean',
#   '(1942)',
#   '',
#   'Male',
#   '1975',
#   'Architecture & Design'],
#  ['The Catboat',
#   'Edward Hopper',
#   'American',
#   '(1882)',
#   '(1967)',
#   'Male',
#   '1922',
#   'Prints & Illustrated Books'],
#  ["Dognat' i peregnat' v tekhniko-ekonomicheskom otnoshenii peredovye kapitalisticheskie strany v 10 let. 70 kartinnye diagrammna otkrytkakh",
#   'Unknown',
#   'Unknow Nationality',
#   '',
#   '',
#   'Gender Unknown',
#   '1931',
#   'Prints & Illustrated Books'],
#  ['Plate (page 11) from The Dive',
#   'Alex Katz',
#   'American',
#   '(1927)',
#   '',
#   'Male',
#   '2011',
#   'Prints & Illustrated Books']]

# %%
mamo_pd.isnull()
# Out:
#        Title  Artist  Nationality  BeginDate  EndDate  Gender   Date  \
# 0      False   False        False      False    False   False  False
# 1      False   False        False      False    False   False  False
# 2      False   False        False      False    False   False  False
# 3      False   False        False      False    False   False  False
# 4      False   False        False      False    False   False  False
# ...      ...     ...          ...        ...      ...     ...    ...
# 16720  False   False        False      False    False   False  False
# 16721  False   False        False      False     True   False  False
# 16722  False   False        False      False    False   False  False
# 16723  False   False        False       True     True   False  False
# 16724  False   False        False      False     True   False  False
#
#        Department
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# ...

# %%
mamo_pd.isnull().sum(axis=0)
# Out:
# Title             1
# Artist            0
# Nationality       0
# BeginDate       939
# EndDate        6251
# Gender            0
# Date              0
# Department        0
# dtype: int64

# %%
bol_s=mamo_pd["Nationality"]==""

# %%
bol_s.sum(axis=0)
# Out:
# 491

# %%
bol_s.sum(axis=0)
# Out:
# 491

# %%
f_d=mamo_pd[bol_s]

# %%
f_d["Nationality"]="unknown nationality"
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7508\276919379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_d["Nationality"]="unknown nationality"

# %%
f_d
# Out:
#                                                    Title            Artist  \
# 31                                              Untitled           Unknown
# 36                            Mandry Ven'iamyna Tret'oho    Moisei Fradkin
# 109                                        Bright Leaves      Ross McElwee
# 137                                              Nations  Slavs and Tatars
# 185                                             Untitled           Unknown
# ...                                                  ...               ...
# 16486                     Festons und Dekorative Gruppen           Unknown
# 16556                                            Rapture           Blondie
# 16661                                   The Hansen Album           Unknown
# 16664                                           Untitled           Unknown
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...           Unknown
#
#                Nationality BeginDate EndDate Gender       Date  \
# ...

# %%
bol_=mamo_pd.loc[bol_s,"Nationality"] = "Nationality Unknown"

# %%
bol_.sum(axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 bol_.sum(axis=0)
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
(mamo_pd["Nationality"]=="").sum()
# Out:
# 0

# %%
mamo_pd["Nationality"]
# Out:
# 0                   American
# 1                    Spanish
# 2                     French
# 3                     French
# 4                     French
#                 ...
# 16720                British
# 16721                Chilean
# 16722               American
# 16723    Nationality Unknown
# 16724               American
# Name: Nationality, Length: 16725, dtype: object

# %%
bol_.sum(axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 bol_.sum(axis=0)
#
# AttributeError: 'str' object has no attribute 'sum'

# %%
mamo_pd.tail()
# Out:
#                                                    Title         Artist  \
# 16720                                   Oval with Points    Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile    Juan Baixas
# 16722                                        The Catboat  Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...        Unknown
# 16724                      Plate (page 11) from The Dive      Alex Katz
#
#                Nationality BeginDate EndDate Gender       Date  \
# 16720              British    (1898)  (1986)   Male  1968-1969
# 16721              Chilean    (1942)     NaN   Male       1975
# 16722             American    (1882)  (1967)   Male       1922
# 16723  Nationality Unknown       NaN     NaN              1931
# 16724             American    (1927)     NaN   Male       2011
#
#                        Department
# 16720        Painting & Sculpture
# 16721       Architecture & Design
# 16722  Prints & Illustrated Books
# ...

# %%
import pandas as pd

# %%
moma_df=pd.read_csv("works.csv")

# %%
moma_df["Nationality"]=moma_df["Nationality"].str.strip("(").str.strip(")").str.title()

# %%
moma_df["Gender"]=moma_df["Gender"].str.strip("(").str.strip(")").str.title()

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate  Gender       Date                  Department
# 0    American    (1947)  (2013)  Female       1986  Prints & Illustrated Books
# 1     Spanish    (1916)  (2007)    Male       1978  Prints & Illustrated Books
# 2      French    (1870)  (1943)    Male  1889-1911  Prints & Illustrated Books
# 3      French    (1861)  (1944)    Male  1927-1940  Prints & Illustrated Books
# 4      French    (1857)  (1927)    Male       1903                 Photography

# %%
(moma_df["Nationality"]=="").sum()
# Out:
# 491

# %%
bol_n=(moma_df["Nationality"]=="")

# %%
moma_df.loc[bol_n,"Nationality"]="Unknown Nationality"

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate  Gender       Date                  Department
# 0    American    (1947)  (2013)  Female       1986  Prints & Illustrated Books
# 1     Spanish    (1916)  (2007)    Male       1978  Prints & Illustrated Books
# 2      French    (1870)  (1943)    Male  1889-1911  Prints & Illustrated Books
# 3      French    (1861)  (1944)    Male  1927-1940  Prints & Illustrated Books
# 4      French    (1857)  (1927)    Male       1903                 Photography

# %%
moma_df["Nationality"].unique()
# Out:
# array(['American', 'Spanish', 'French', 'South African', 'Canadian',
#        'Czech', 'Belgian', 'Russian', 'British', 'German',
#        'Unknown Nationality', 'Swiss', 'Polish', 'Japanese', 'Portuguese',
#        'Austrian', 'Australian', 'Italian', 'Chilean', 'Colombian',
#        'Mexican', 'Brazilian', 'Dutch', 'Romanian', 'Venezuelan',
#        'Korean', 'Israeli', 'Argentine', 'Indian', 'Nationality Unknown',
#        'Swedish', 'Yugoslav', 'Cuban', 'Various', 'Luxembourgish',
#        'Croatian', 'Bulgarian', 'Hungarian', 'Georgian', 'Puerto Rican',
#        'Danish', 'Serbian', 'Pakistani', 'Ecuadorian', 'Chinese',
#        'Iranian', 'Finnish', 'Lebanese', 'Thai', 'Cambodian', 'Scottish',
#        'Kenyan', 'Latvian', 'Sudanese', 'Uruguayan', 'Peruvian',
#        'New Zealander', 'Moroccan', 'Guatemalan', 'Cameroonian',
#        'Egyptian', 'Nigerian', 'Icelandic', 'Haitian', 'Tajik', 'Irish',
#        'Norwegian', 'Costa Rican', 'Slovenian', 'Turkish', 'Mozambican',
# ...

# %%
(moma_df["Gender"]=="").sum()
# Out:
# 791

# %%
bol_g=(moma_df["Gender"]=="")

# %%
moma_df[bol_g]
# Out:
#                                                    Title  \
# 31                                              Untitled
# 90                                             Bar Tools
# 137                                              Nations
# 177    El Frente Popular de Madrid Al Frente Popular ...
# 185                                             Untitled
# ...                                                  ...
# 16664                                           Untitled
# 16670                                Inflatable Armchair
# 16688             Poster of the French National Railroad
# 16702                                  Salon de la Plume
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...
#
#                            Artist          Nationality BeginDate EndDate  \
# 31                        Unknown  Unknown Nationality       NaN     NaN
# 90                     Studio Opi              Italian    (1955)     NaN
# ...

# %%
moma_df.loc[bol_g,"Gender"]="Unknown Gender"

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate  Gender       Date                  Department
# 0    American    (1947)  (2013)  Female       1986  Prints & Illustrated Books
# 1     Spanish    (1916)  (2007)    Male       1978  Prints & Illustrated Books
# 2      French    (1870)  (1943)    Male  1889-1911  Prints & Illustrated Books
# 3      French    (1861)  (1944)    Male  1927-1940  Prints & Illustrated Books
# 4      French    (1857)  (1927)    Male       1903                 Photography

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16725 entries, 0 to 16724
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        16724 non-null  object
#  1   Artist       16725 non-null  object
#  2   Nationality  16725 non-null  object
#  3   BeginDate    15786 non-null  object
#  4   EndDate      10474 non-null  object
#  5   Gender       16725 non-null  object
#  6   Date         16725 non-null  object
#  7   Department   16725 non-null  object
# dtypes: object(8)
# memory usage: 1.0+ MB

# %%
moma_df.dtypes
# Out:
# Title          object
# Artist         object
# Nationality    object
# BeginDate      object
# EndDate        object
# Gender         object
# Date           object
# Department     object
# dtype: object

# %%
moma_df["BeginDate"].dtype
# Out:
# dtype('O')

# %%
moma_df["BeginDate"]=moma_df["BeginDate"].str.strip("(").str.strip(")")

# %%
moma_df["EndDate"]=moma_df["EndDate"].str.strip("(").str.strip(")")

# %%
moma_df["BeginDate"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 moma_df["BeginDate"].astype(int)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
for i in moma_df["BeginDate"]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
for i in moma_df["BeginDate"]:
    print(int(i))
# Out:
# 1947
# 1916
# 1870
# 1861
# 1857
# 1919
# 1857
# 1928
# 1964
# 1882
# 1901
# 1935
# 1871
# 1894
# 1955
# 1878
# 1927
# 1936
# 1867
# 1932
# 1886
# 1894
# 1938
# 1926
# 1898
# 1867
# 1947
# 1868
# 1857
# 1938
# 1889
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 for i in moma_df["BeginDate"]:
# ----> 2     print(int(i))
#
# ValueError: cannot convert float NaN to integer

# %%
moma_df["BeginDate"]=moma_df["BeginDate"].astype(float)
moma_df["EndDate"]=moma_df["EndDate"].astype(float)

# %%
moma_df["EndDate"].dtype
# Out:
# dtype('float64')

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality  BeginDate  EndDate  Gender       Date  \
# 0    American     1947.0   2013.0  Female       1986
# 1     Spanish     1916.0   2007.0    Male       1978
# 2      French     1870.0   1943.0    Male  1889-1911
# 3      French     1861.0   1944.0    Male  1927-1940
# 4      French     1857.0   1927.0    Male       1903
#
#                    Department
# 0  Prints & Illustrated Books
# 1  Prints & Illustrated Books
# 2  Prints & Illustrated Books
# 3  Prints & Illustrated Books
# 4                 Photography

# %%
bad_char=["(",")","C","c", ".", " ","s", "'"]

# %%
date = "(c. 1987'c)"

# %%
for i in bad_char:
    date=date_.replace(i,"")

# %%
date
for i in bad_char:
    date=date.replace(i,"")
date
'1987'
# Out:
# '(1945C.)'

# %%
date
# Out:
# '(1945C.)'

# %%
for i in bad_char:
    date=date.replace(i,"")

# %%
date
# Out:
# '1987'

# %%
def clean_date(date):
    bad_char=["(",")","C","c", ".", " ","s", "'"]
    for i in bad_char:
        date=date.replace(i,"")
    return date

# %%
clean_date("149Cs")
# Out:
# '149'

# %%
clean_data=[]
for i in moma_df["Date"]:
    cd= clean_date(i)
    clean_data.append(cd)

# %%
print(clean_data)
# Out:
# ['1986', '1978', '1889-1911', '1927-1940', '1903', '1957', '1924', '1978-1983', '2001', '1941', '1949-1950', '1963', '1908-1911', '1934', '1997', '1931-1933', '1972', '1967', '1923-1924', '1979', '1925-1927', '1929', '1972', '1974', '1957', '1920-1930', '1974', '1915', '1912', '1988-1990', '1925', '1925', '1980', '1964', '1968', '1969', '1934', '1953', '1971', '1988', '1818', '2002', '1926', '1969', '1914', '1979', '1968', '1979', '1966', '1904', '1949', '1981', '1970', '1969', '1972', '1923-1925', '1967', '1932', '1928', '1965', '2003', '1971-1974', '1983', '1930', '1946', '1984', '2006', '1885', '1942', '1913', '2015', '1987', '1947-1949', '1965', '1818', '1961', '1925', '1916-1932', '1962', '1944', '1930', '1991', '1991-1994', '2008', '1975', '1893', '1966', '1968-1969', '1964-1968', '1928-1939', '1969', '1942', '1980', '1955', '1930', '1955-1960', '1922', '1934', '1903', '2008', '1962', '1944', '1914-1918', '2003', '2012', '1965', '1865', '1976', '1902', '2003', '2010', '1944', '
# ...

# %%
moma_df["Date"]=moma_df["Date"].apply(clean_date)

# %%
moma_df.head(50)
# Out:
#                                                 Title  \
# 0                      Dress MacLeod from Tartan Sets
# 1   Duplicate of plate from folio 11 verso (supple...
# 2                    Tailpiece (page 55) from SAGESSE
# 3   Headpiece (page 129) from LIVRET DE FOLASTRIES...
# 4                                       97 rue du Bac
# 5         Pictorial ornament (folio 11) from WOODCUTS
# 6                             Rue de l'Hôtel-de-Ville
# 7                                 Los Angeles Airport
# 8                    Why Defy from Disasters of Peace
# 9                                STILL WATER AND FISH
# 10        In-text plate (folio 11) from LA MÉTROMANIE
# 11                                     Black Bathroom
# 12           In-text plate (page 108) from LYSISTRATA
# 13              Transcendence. Designs for the Ballet
# 14                                           Untitled
# 15                                     Isadora Duncan
# ...

# %%
dle="1990-1995"

# %%
dle=dle.split("-")

# %%
dle
# Out:
# ['1990', '1995']

# %%
dle_u=(int(dle[0])+int(dle[1]))//2

# %%
dle_u
# Out:
# 1992

# %%
moma_df["Date"]=moma_df["Date"].apply(date_w)

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality  BeginDate  EndDate  Gender  Date                  Department
# 0    American     1947.0   2013.0  Female  1986  Prints & Illustrated Books
# 1     Spanish     1916.0   2007.0    Male  1978  Prints & Illustrated Books
# 2      French     1870.0   1943.0    Male  1900  Prints & Illustrated Books
# 3      French     1861.0   1944.0    Male  1933  Prints & Illustrated Books
# 4      French     1857.0   1927.0    Male  1903                 Photography

# %%
moma_df.to_csv("work_clean.csv",index=False)

# %%
def date_w(date):
    if "-" in date:
        d=date.split('-')
        date=(int(d[0])+int(d[1]))//2
    else:
        date
    return date
