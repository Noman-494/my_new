# %%
import func

# %%
import pandas as pd

# %%
header, moma = func.read_csv("works.csv")

# %%
type(moma)
# Out:
# list

# %%
header
# Out:
# ['Title',
#  'Artist',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Department']

# %%
moma_df = pd.read_csv("works.csv")

# %%
type(moma_df)
# Out:
# pandas.core.frame.DataFrame

# %%
moma_df.ndim
# Out:
# 2

# %%
moma_df.shape
# Out:
# (16725, 8)

# %%
len(moma)
# Out:
# 16725

# %%
len(header)
# Out:
# 8

# %%
for row in moma[:5]:
    nat = row[2]
    gen = row[-3]
    print(nat, gen)
# Out:
# (American) (Female)
# (Spanish) (Male)
# (French) (Male)
# (French) (Male)
# (French) (Male)

# %%
name = "(Wa(qas)("

name = name.replace("(","")
name = name.strip(")")
name
# Out:
# 'Waqas'

# %%
name = "(Wa(qas)"

name.replace("(","").strip(")")
# Out:
# 'Waqas'

# %%
for row in moma[:5]:
    nat = row[2]
    gen = row[-3]
    
    nat = nat.strip("(").strip(")")
    gen = gen.replace("(","").replace(")","")
    print(nat, gen)
# Out:
# American Female
# Spanish Male
# French Male
# French Male
# French Male

# %%
for row in moma:
    nat = row[2]
    gen = row[-3]
    
    nat = nat.strip("(").strip(")")
    gen = gen.replace("(","").replace(")","")
    
    row[2] = nat
    row[-3] = gen

# %%
# for row in moma:

#     row[2] = row[2].strip("(").strip(")") # nationality
#     row[-3]= row[-3].replace("(","").replace(")","") # gender

# %%
print(moma[:5])
# Out:
# [['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books'], ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books'], ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books'], ['Headpiece (page 129) from LIVRET DE FOLASTRIES, Ã\x80 JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books'], ['97 rue du Bac', 'EugÃ¨ne Atget', 'French', '(1857)', '(1927)', 'Male', '1903', 'Photography']]

# %%
moma_df
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
moma_df.head()
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3  Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                      97 rue du Bac        Eugène Atget
#
#   Nationality BeginDate EndDate    Gender       Date  \
# 0  (American)    (1947)  (2013)  (Female)       1986
# 1   (Spanish)    (1916)  (2007)    (Male)       1978
# 2    (French)    (1870)  (1943)    (Male)  1889-1911
# 3    (French)    (1861)  (1944)    (Male)  1927-1940
# 4    (French)    (1857)  (1927)    (Male)       1903
#
#                    Department
# 0  Prints & Illustrated Books
# 1  Prints & Illustrated Books
# 2  Prints & Illustrated Books
# 3  Prints & Illustrated Books
# 4                 Photography

# %%
moma_df.head(3)
# Out:
#                                                Title              Artist  \
# 0                     Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1  Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                   Tailpiece (page 55) from SAGESSE       Maurice Denis
#
#   Nationality BeginDate EndDate    Gender       Date  \
# 0  (American)    (1947)  (2013)  (Female)       1986
# 1   (Spanish)    (1916)  (2007)    (Male)       1978
# 2    (French)    (1870)  (1943)    (Male)  1889-1911
#
#                    Department
# 0  Prints & Illustrated Books
# 1  Prints & Illustrated Books
# 2  Prints & Illustrated Books

# %%
print(moma[-5:])
# Out:
# [['Oval with Points', 'Henry Moore', 'British', '(1898)', '(1986)', 'Male', '1968-1969', 'Painting & Sculpture'], ['Cementerio de la Ciudad Abierta, Ritoque, Chile', 'Juan Baixas', 'Chilean', '(1942)', '', 'Male', '1975', 'Architecture & Design'], ['The Catboat', 'Edward Hopper', 'American', '(1882)', '(1967)', 'Male', '1922', 'Prints & Illustrated Books'], ["Dognat' i peregnat' v tekhniko-ekonomicheskom otnoshenii peredovye kapitalisticheskie strany v 10 let. 70 kartinnye diagrammna otkrytkakh", 'Unknown', '', '', '', '', '1931', 'Prints & Illustrated Books'], ['Plate (page 11) from The Dive', 'Alex Katz', 'American', '(1927)', '', 'Male', '2011', 'Prints & Illustrated Books']]

# %%
moma_df.tail()
# Out:
#                                                    Title         Artist  \
# 16720                                   Oval with Points    Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile    Juan Baixas
# 16722                                        The Catboat  Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...        Unknown
# 16724                      Plate (page 11) from The Dive      Alex Katz
#
#       Nationality BeginDate EndDate  Gender       Date  \
# 16720   (British)    (1898)  (1986)  (Male)  1968-1969
# 16721   (Chilean)    (1942)     NaN  (Male)       1975
# 16722  (American)    (1882)  (1967)  (Male)       1922
# 16723          ()       NaN     NaN      ()       1931
# 16724  (American)    (1927)     NaN  (Male)       2011
#
#                        Department
# 16720        Painting & Sculpture
# 16721       Architecture & Design
# 16722  Prints & Illustrated Books
# 16723  Prints & Illustrated Books
# ...

# %%
# DataFrame -> SIMD

# %%
moma_df["Nationality"]
# Out:
# 0        (American)
# 1         (Spanish)
# 2          (French)
# 3          (French)
# 4          (French)
#             ...
# 16720     (British)
# 16721     (Chilean)
# 16722    (American)
# 16723            ()
# 16724    (American)
# Name: Nationality, Length: 16725, dtype: object

# %%
for row in moma:
    print(row[2])
# Out:
# American
# Spanish
# French
# French
# French
# American
# French
# American
# South African
# Canadian
# French
# American
# Czech
# American
# American
# American
# Belgian
# American
# American
# Spanish
# American
# Russian
# American
# French
# French
# French
# British
# French
# French
# German
# Belgian
#
# American
# American
# American
# Swiss
#
# American
# American
# Polish
# British
# American
# American
# Belgian
# American
# Japanese
# American
# American
# Spanish
# American
# French
# American
# American
# American
# American
# French
# American
# American
# French
# American
# American
# Portuguese
# American
# American
# Austrian
# Swiss
# German
# American
# American
# French
# British
# American
# French
# American
# British
# German
# French
# French
# Australian
# American
# French
# Spanish
# German
# American
# American
# French
# American
# American
# American
# French
# Italian
# American
# American
# American
# American
# American
# French
# American
# ...

# %%
type(moma_df["Nationality"])
# Out:
# pandas.core.series.Series

# %%
moma_df["Nationality"].ndim
# Out:
# 1

# %%
moma_df["Nationality"]
# Out:
# 0        (American)
# 1         (Spanish)
# 2          (French)
# 3          (French)
# 4          (French)
#             ...
# 16720     (British)
# 16721     (Chilean)
# 16722    (American)
# 16723            ()
# 16724    (American)
# Name: Nationality, Length: 16725, dtype: object

# %%
"waqas".append

# %%
moma_df["Nationality"].str.strip("(").str.replace(")","")
# Out:
# 0        American
# 1         Spanish
# 2          French
# 3          French
# 4          French
#            ...
# 16720     British
# 16721     Chilean
# 16722    American
# 16723
# 16724    American
# Name: Nationality, Length: 16725, dtype: object

# %%
moma_df["Nationality"] = moma_df["Nationality"].str.strip("(").str.replace(")","")

# %%
moma_df
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
moma_df.columns # attribute
# Out:
# Index(['Title', 'Artist', 'Nationality', 'BeginDate', 'EndDate', 'Gender',
#        'Date', 'Department'],
#       dtype='object')

# %%
moma_df['Gender'] = moma_df['Gender'].str.strip("(").str.replace(")","")

# %%
moma_df
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
moma_lst = moma.copy()

# %%
name = "muhammad waqas"

name.upper()
# Out:
# 'MUHAMMAD WAQAS'

# %%
name.title()
# Out:
# 'Muhammad Waqas'

# %%
for row in moma_lst:
    nat = row[2].title()
    if nat == "":
        nat = "Nationality Unknown"
    row[2] = nat

# %%
moma_lst[-5:]
# Out:
# [['Oval with Points',
#   'Henry Moore',
#   'British',
#   '(1898)',
#   '(1986)',
#   'Male',
#   '1968-1969',
#   'Painting & Sculpture'],
#  ['Cementerio de la Ciudad Abierta, Ritoque, Chile',
#   'Juan Baixas',
#   'Chilean',
#   '(1942)',
#   '',
#   'Male',
#   '1975',
#   'Architecture & Design'],
#  ['The Catboat',
#   'Edward Hopper',
#   'American',
#   '(1882)',
#   '(1967)',
#   'Male',
#   '1922',
#   'Prints & Illustrated Books'],
#  ["Dognat' i peregnat' v tekhniko-ekonomicheskom otnoshenii peredovye kapitalisticheskie strany v 10 let. 70 kartinnye diagrammna otkrytkakh",
#   'Unknown',
#   'Nationality Unknown',
#   '',
#   '',
#   '',
#   '1931',
#   'Prints & Illustrated Books'],
#  ['Plate (page 11) from The Dive',
#   'Alex Katz',
#   'American',
#   '(1927)',
#   '',
#   'Male',
#   '2011',
#   'Prints & Illustrated Books']]

# %%
# for row in moma_lst:
#     gen = row[-3].title()
#     if gen == "":
#         gen = "Gender Unknown"
#     row[-3] = gen

# %%
for row in moma_lst:
    row[-3] = row[-3].title()
    if row[-3]== "":
        row[-3] = "Gender Unknown"

# %%
moma_lst[-5:]
# Out:
# [['Oval with Points',
#   'Henry Moore',
#   'British',
#   '(1898)',
#   '(1986)',
#   'Male',
#   '1968-1969',
#   'Painting & Sculpture'],
#  ['Cementerio de la Ciudad Abierta, Ritoque, Chile',
#   'Juan Baixas',
#   'Chilean',
#   '(1942)',
#   '',
#   'Male',
#   '1975',
#   'Architecture & Design'],
#  ['The Catboat',
#   'Edward Hopper',
#   'American',
#   '(1882)',
#   '(1967)',
#   'Male',
#   '1922',
#   'Prints & Illustrated Books'],
#  ["Dognat' i peregnat' v tekhniko-ekonomicheskom otnoshenii peredovye kapitalisticheskie strany v 10 let. 70 kartinnye diagrammna otkrytkakh",
#   'Unknown',
#   'Nationality Unknown',
#   '',
#   '',
#   'Gender Unknown',
#   '1931',
#   'Prints & Illustrated Books'],
#  ['Plate (page 11) from The Dive',
#   'Alex Katz',
#   'American',
#   '(1927)',
#   '',
#   'Male',
#   '2011',
#   'Prints & Illustrated Books']]

# %%
moma_df["Nationality"]
# Out:
# 0        American
# 1         Spanish
# 2          French
# 3          French
# 4          French
#            ...
# 16720     British
# 16721     Chilean
# 16722    American
# 16723
# 16724    American
# Name: Nationality, Length: 16725, dtype: object

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16725 entries, 0 to 16724
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        16724 non-null  object
#  1   Artist       16725 non-null  object
#  2   Nationality  16725 non-null  object
#  3   BeginDate    15786 non-null  object
#  4   EndDate      10474 non-null  object
#  5   Gender       16725 non-null  object
#  6   Date         16725 non-null  object
#  7   Department   16725 non-null  object
# dtypes: object(8)
# memory usage: 1.0+ MB

# %%
name = ""
type(name)
# Out:
# str

# %%
name = None

type(name)
# Out:
# NoneType

# %%
moma_df.isnull()
# Out:
#        Title  Artist  Nationality  BeginDate  EndDate  Gender   Date  \
# 0      False   False        False      False    False   False  False
# 1      False   False        False      False    False   False  False
# 2      False   False        False      False    False   False  False
# 3      False   False        False      False    False   False  False
# 4      False   False        False      False    False   False  False
# ...      ...     ...          ...        ...      ...     ...    ...
# 16720  False   False        False      False    False   False  False
# 16721  False   False        False      False     True   False  False
# 16722  False   False        False      False    False   False  False
# 16723  False   False        False       True     True   False  False
# 16724  False   False        False      False     True   False  False
#
#        Department
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# ...

# %%
moma_df.isnull().sum(axis = 0)
# Out:
# Title             1
# Artist            0
# Nationality       0
# BeginDate       939
# EndDate        6251
# Gender            0
# Date              0
# Department        0
# dtype: int64

# %%
16725-15786
# Out:
# 939

# %%
moma_df.isnull().sum(axis = "index")
# Out:
# Title             1
# Artist            0
# Nationality       0
# BeginDate       939
# EndDate        6251
# Gender            0
# Date              0
# Department        0
# dtype: int64

# %%
moma_df.isnull().sum(axis = 1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16720    0
# 16721    1
# 16722    0
# 16723    2
# 16724    1
# Length: 16725, dtype: int64

# %%
moma_df.isnull().sum(axis = "columns")
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16720    0
# 16721    1
# 16722    0
# 16723    2
# 16724    1
# Length: 16725, dtype: int64

# %%
moma_df.isnull().sum()
# Out:
# Title             1
# Artist            0
# Nationality       0
# BeginDate       939
# EndDate        6251
# Gender            0
# Date              0
# Department        0
# dtype: int64

# %%
moma_df.notnull().sum()
# Out:
# Title          16724
# Artist         16725
# Nationality    16725
# BeginDate      15786
# EndDate        10474
# Gender         16725
# Date           16725
# Department     16725
# dtype: int64

# %%
moma_df["Nationality"]
# Out:
# 0        American
# 1         Spanish
# 2          French
# 3          French
# 4          French
#            ...
# 16720     British
# 16721     Chilean
# 16722    American
# 16723
# 16724    American
# Name: Nationality, Length: 16725, dtype: object

# %%
bol_s = moma_df["Nationality"] == "" # it is not missing
bol_s
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16720    False
# 16721    False
# 16722    False
# 16723     True
# 16724    False
# Name: Nationality, Length: 16725, dtype: bool

# %%
bol_s.sum()
# Out:
# 491

# %%
f_df = moma_df[bol_s]
f_df
# Out:
#                                                    Title            Artist  \
# 31                                              Untitled           Unknown
# 36                            Mandry Ven'iamyna Tret'oho    Moisei Fradkin
# 109                                        Bright Leaves      Ross McElwee
# 137                                              Nations  Slavs and Tatars
# 185                                             Untitled           Unknown
# ...                                                  ...               ...
# 16486                     Festons und Dekorative Gruppen           Unknown
# 16556                                            Rapture           Blondie
# 16661                                   The Hansen Album           Unknown
# 16664                                           Untitled           Unknown
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...           Unknown
#
#       Nationality BeginDate EndDate Gender       Date  \
# ...

# %%
f_df["Nationality"] = "Nationality Unknown"
# Out:
# C:\Users\CGDC\AppData\Local\Temp\ipykernel_6044\2612410602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_df["Nationality"] = "Nationality Unknown"

# %%
f_df
# Out:
#                                                    Title            Artist  \
# 31                                              Untitled           Unknown
# 36                            Mandry Ven'iamyna Tret'oho    Moisei Fradkin
# 109                                        Bright Leaves      Ross McElwee
# 137                                              Nations  Slavs and Tatars
# 185                                             Untitled           Unknown
# ...                                                  ...               ...
# 16486                     Festons und Dekorative Gruppen           Unknown
# 16556                                            Rapture           Blondie
# 16661                                   The Hansen Album           Unknown
# 16664                                           Untitled           Unknown
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...           Unknown
#
#                Nationality BeginDate EndDate Gender       Date  \
# ...

# %%
moma_df["Nationality"] == ""
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16720    False
# 16721    False
# 16722    False
# 16723     True
# 16724    False
# Name: Nationality, Length: 16725, dtype: bool

# %%
moma_df[bol_
        s]["Nationality"] = "Nationality Unknown"
# Out:
# C:\Users\CGDC\AppData\Local\Temp\ipykernel_6044\1664649084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moma_df[bol_s]["Nationality"] = "Nationality Unknown"

# %%
(moma_df["Nationality"] == "").sum()
# Out:
# 491

# %%
moma_df.loc[bol_s,"Nationality"] = "Nationality Unknown"

# %%
bole = moma_df["Nationality"] == ""

# %%
bole.sum()
# Out:
# 0

# %%
moma_df["Title"]
# Out:
# 0                           Dress MacLeod from Tartan Sets
# 1        Duplicate of plate from folio 11 verso (supple...
# 2                         Tailpiece (page 55) from SAGESSE
# 3        Headpiece (page 129) from LIVRET DE FOLASTRIES...
# 4                                            97 rue du Bac
#                                ...
# 16720                                     Oval with Points
# 16721      Cementerio de la Ciudad Abierta, Ritoque, Chile
# 16722                                          The Catboat
# 16723    Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# 16724                        Plate (page 11) from The Dive
# Name: Title, Length: 16725, dtype: object

# %%
moma_df["Date"]
# Out:
# 0             1986
# 1             1978
# 2        1889-1911
# 3        1927-1940
# 4             1903
#            ...
# 16720    1968-1969
# 16721         1975
# 16722         1922
# 16723         1931
# 16724         2011
# Name: Date, Length: 16725, dtype: object

# %%
moma_df
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
moma_df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ...

# %%
moma_df.iloc[-1]
# Out:
# Title          Plate (page 11) from The Dive
# Artist                             Alex Katz
# Nationality                         American
# BeginDate                             (1927)
# EndDate                                  NaN
# Gender                                  Male
# Date                                    2011
# Department        Prints & Illustrated Books
# Name: 16724, dtype: object

# %%
moma_df.tail(1)
# Out:
#                                Title     Artist Nationality BeginDate EndDate  \
# 16724  Plate (page 11) from The Dive  Alex Katz    American    (1927)     NaN
#
#       Gender  Date                  Department
# 16724   Male  2011  Prints & Illustrated Books

# %%
moma_df.iloc[0]
# Out:
# Title          Dress MacLeod from Tartan Sets
# Artist                     Sarah Charlesworth
# Nationality                          American
# BeginDate                              (1947)
# EndDate                                (2013)
# Gender                                 Female
# Date                                     1986
# Department         Prints & Illustrated Books
# Name: 0, dtype: object

# %%
moma_df.head(1)
# Out:
#                             Title              Artist Nationality BeginDate  \
# 0  Dress MacLeod from Tartan Sets  Sarah Charlesworth    American    (1947)
#
#   EndDate  Gender  Date                  Department
# 0  (2013)  Female  1986  Prints & Illustrated Books

# %%
moma_df
# Out:
#                                                    Title              Artist  \
# 0                         Dress MacLeod from Tartan Sets  Sarah Charlesworth
# 1      Duplicate of plate from folio 11 verso (supple...     Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE       Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...    Aristide Maillol
# 4                                          97 rue du Bac        Eugène Atget
# ...                                                  ...                 ...
# 16720                                   Oval with Points         Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile         Juan Baixas
# 16722                                        The Catboat       Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...             Unknown
# 16724                      Plate (page 11) from The Dive           Alex Katz
#
# ...

# %%
m = moma_df.copy()

# %%
m = m.set_index("Nationality")

# %%
m
# Out:
#                                                                  Title  \
# Nationality
# American                                Dress MacLeod from Tartan Sets
# Spanish              Duplicate of plate from folio 11 verso (supple...
# French                                Tailpiece (page 55) from SAGESSE
# French               Headpiece (page 129) from LIVRET DE FOLASTRIES...
# French                                                   97 rue du Bac
# ...                                                                ...
# British                                               Oval with Points
# Chilean                Cementerio de la Ciudad Abierta, Ritoque, Chile
# American                                                   The Catboat
# Nationality Unknown  Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# American                                 Plate (page 11) from The Dive
#
#                                  Artist BeginDate EndDate  Gender       Date  \
# Nationality
# ...

# %%
m.columns
# Out:
# Index(['Title', 'Artist', 'BeginDate', 'EndDate', 'Gender', 'Date',
#        'Department'],
#       dtype='object')

# %%
m
# Out:
#                                                                  Title  \
# Nationality
# American                                Dress MacLeod from Tartan Sets
# Spanish              Duplicate of plate from folio 11 verso (supple...
# French                                Tailpiece (page 55) from SAGESSE
# French               Headpiece (page 129) from LIVRET DE FOLASTRIES...
# French                                                   97 rue du Bac
# ...                                                                ...
# British                                               Oval with Points
# Chilean                Cementerio de la Ciudad Abierta, Ritoque, Chile
# American                                                   The Catboat
# Nationality Unknown  Dognat' i peregnat' v tekhniko-ekonomicheskom ...
# American                                 Plate (page 11) from The Dive
#
#                                  Artist BeginDate EndDate  Gender       Date  \
# Nationality
# ...

# %%
m.loc["American"]
# Out:
#                                                          Title  \
# Nationality
# American                        Dress MacLeod from Tartan Sets
# American           Pictorial ornament (folio 11) from WOODCUTS
# American                                   Los Angeles Airport
# American                                        Black Bathroom
# American                 Transcendence. Designs for the Ballet
# ...                                                        ...
# American     Cantor Drive-in Restaurant, Indianapolis, IN, ...
# American     Untitled (Edward and Clara Smith Steichen On T...
# American                                             High Peak
# American                                           The Catboat
# American                         Plate (page 11) from The Dive
#
#                                 Artist BeginDate EndDate  Gender       Date  \
# Nationality
# American            Sarah Charlesworth    (1947)  (2013)  Female       1986
# ...

# %%
m.iloc[0]
# Out:
# Title         Dress MacLeod from Tartan Sets
# Artist                    Sarah Charlesworth
# BeginDate                             (1947)
# EndDate                               (2013)
# Gender                                Female
# Date                                    1986
# Department        Prints & Illustrated Books
# Name: American, dtype: object

# %%
moma_df.iloc[0]
# Out:
# Title          Dress MacLeod from Tartan Sets
# Artist                     Sarah Charlesworth
# Nationality                          American
# BeginDate                              (1947)
# EndDate                                (2013)
# Gender                                 Female
# Date                                     1986
# Department         Prints & Illustrated Books
# Name: 0, dtype: object

# %%
moma_df.loc[0]
# Out:
# Title          Dress MacLeod from Tartan Sets
# Artist                     Sarah Charlesworth
# Nationality                          American
# BeginDate                              (1947)
# EndDate                                (2013)
# Gender                                 Female
# Date                                     1986
# Department         Prints & Illustrated Books
# Name: 0, dtype: object

# %%
moma_df.drop(0, inplace = True)

# %%
moma_df
# Out:
#                                                    Title            Artist  \
# 1      Duplicate of plate from folio 11 verso (supple...   Pablo Palazuelo
# 2                       Tailpiece (page 55) from SAGESSE     Maurice Denis
# 3      Headpiece (page 129) from LIVRET DE FOLASTRIES...  Aristide Maillol
# 4                                          97 rue du Bac      Eugène Atget
# 5            Pictorial ornament (folio 11) from WOODCUTS  Antonio Frasconi
# ...                                                  ...               ...
# 16720                                   Oval with Points       Henry Moore
# 16721    Cementerio de la Ciudad Abierta, Ritoque, Chile       Juan Baixas
# 16722                                        The Catboat     Edward Hopper
# 16723  Dognat' i peregnat' v tekhniko-ekonomicheskom ...           Unknown
# 16724                      Plate (page 11) from The Dive         Alex Katz
#
#                Nationality BeginDate EndDate Gender       Date  \
# ...

# %%
moma_df.iloc[0]
# Out:
# Title          Duplicate of plate from folio 11 verso (supple...
# Artist                                           Pablo Palazuelo
# Nationality                                              Spanish
# BeginDate                                                 (1916)
# EndDate                                                   (2007)
# Gender                                                      Male
# Date                                                        1978
# Department                            Prints & Illustrated Books
# Name: 1, dtype: object

# %%
moma_df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 moma_df.loc[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
bol_s
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16720    False
# 16721    False
# 16722    False
# 16723     True
# 16724    False
# Name: Nationality, Length: 16725, dtype: bool

# %%
bol_s.sum()
# Out:
# 491

# %%
(moma_df["Nationality"] == "").sum()
# Out:
# 0
