# %%
import pandas as pd

# %%
import csv

# %%
T20matches_pd=pd.read_csv("t20_matches.csv")

# %%
T20matches_pd.head()
# Out:
#    match_id  series_id                                      match_details  \
# 0    304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1    129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2    129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3    304745     124121  South Group:Surrey v Middlesex at The Oval- Ju...
# 4    304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# 1                            Hampshire won by 5 runs
# 2                        Warwickshire won by 19 runs
# 3   Surrey won by 4 wickets (with 4 balls remaining)
# 4  Worcestershire won by 1 wicket (with 2 balls r...
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# ...

# %% [markdown]
# ## opening statement:
#  ###

# %% [markdown]
# I have data set of the Match details of over 6000 T20 matches, including innings scores and results.I will try to perform the analysis through pandas and python on the role of pakistan cricket team with different angles.

# %%
# I want firslty how many series are played in the data

# %%
T20matches_pd
# Out:
#       match_id  series_id                                      match_details  \
# 0       304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1       129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2       129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3       304745     124121  South Group:Surrey v Middlesex at The Oval- Ju...
# 4       304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# ...        ...        ...                                                ...
# 6412   1083450    1083439  2nd T20I:Sri Lanka v Bangladesh at Colombo (RP...
# 6413   1082591    1078425  1st match:Sunrisers Hyderabad v Royal Challeng...
# 6414   1082592    1078425  2nd match:Rising Pune Supergiant v Mumbai Indi...
# 6415   1082593    1078425  3rd match:Gujarat Lions v Kolkata Knight Rider...
# 6416   1082594    1078425  4th match:Kings XI Punjab v Rising Pune Superg...
#
# ...

# %%
T20matches_pd.series_id.value_counts()
# Out:
# series_id
# 435130    151
# 491208    151
# 691693    133
# 946653    133
# 803393    133
#          ...
# 403364      1
# 255956      1
# 463138      1
# 521213      1
# 534188      1
# Name: count, Length: 371, dtype: int64

# %%
with open("t20_matches.csv") as f:
    t20_matches=list(csv.reader(f))

# %%
header=t20_matches[0]
data=t20_matches[1:]

# %%
Serious_counts={}
for i in data:
    series=i[1]
    if series not in Serious_counts:
        Serious_counts[series] =1
    else:
        Serious_counts[series] +=1

# %%
len(Serious_counts)
# Out:
# 371

# %%
# 6417 matches has been played in 371 serious.

# %%
# Another dataset has name of the series and winner of the series.

# %%
series_pd=pd.read_csv("t20_series.csv")

# %%
series_pd.loc[:,["series","winner"]]
# Out:
#                                                 series       winner
# 0                                         Twenty20 Cup       Surrey
# 1         Standard Bank Pro20 Series (in South Africa)       Eagles
# 2                            Twenty20 Cup (in England)        Leics
# 3                  Twenty-20 Tournament (in Sri Lanka)       Chilaw
# 4                  Australia in New Zealand T20I Match    Australia
# ..                                                 ...          ...
# 368  Pakistan Super League (in Pakistan/United Arab...        Zalmi
# 369       Afghanistan v Ireland T20I Series (in India)  Afghanistan
# 370                Pakistan in West Indies T20I Series     Pakistan
# 371                Bangladesh in Sri Lanka T20I Series        drawn
# 372                   Indian Premier League (in India)            -
#
# [373 rows x 2 columns]

# %%
series_pd["winner"]=="Pakistan"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 368    False
# 369    False
# 370     True
# 371    False
# 372    False
# Name: winner, Length: 373, dtype: bool

# %%
series_pd[series_pd["winner"]=="Pakistan"]
# Out:
#                                                 series   season    winner  \
# 22                      Pakistan in England T20I Match     2006  Pakistan
# 49                   Bangladesh in Pakistan T20I Match  2007/08  Pakistan
# 75   Australia v Pakistan T20I Match (in United Ara...     2009  Pakistan
# 79                     ICC World Twenty20 (in England)     2009  Pakistan
# 83                    Pakistan in Sri Lanka T20I Match     2009  Pakistan
# 88   Pakistan v New Zealand T20I Series (in United ...  2009/10  Pakistan
# 114  MCC Spirit of Cricket T20I Series (Australia, ...     2010  Pakistan
# 143                   Pakistan in Zimbabwe T20I Series     2011  Pakistan
# 154  Pakistan v Sri Lanka T20I Match (in United Ara...  2011/12  Pakistan
# 155                  Pakistan in Bangladesh T20I Match  2011/12  Pakistan
# 188  Pakistan v Australia T20I Series (in United Ar...     2012  Pakistan
# 208               Pakistan in South Africa T20I Series  2012/13  Pakistan
# ...

# %%
# I got the detail of the series won by the Pakistan.

# %%
# now i want how many matches pakistan won and secondly how many pakistan won in home country.

# %%
(T20matches_pd["winner"] == "Pakistan") & (T20matches_pd["home"] == "Pakistan")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6412    False
# 6413    False
# 6414    False
# 6415    False
# 6416    False
# Length: 6417, dtype: bool

# %%
T20matches_pd[T20matches_pd["winner"]=="Pakistan"]
# Out:
#       match_id  series_id                                      match_details  \
# 480     225263     224904  Only T20I:England v Pakistan at Bristol- Aug 2...
# 750     306986     306979  1st Match:Pakistan v Uganda at Nairobi (Gym)- ...
# 753     306989     306979  4th Match:Bangladesh v Pakistan at Nairobi (Gy...
# 755     306991     306979  6th Match:Kenya v Pakistan at Nairobi (Gym)- S...
# 758     287855     286109  3rd Match, Group D:Pakistan v Scotland at Durb...
# ...        ...        ...                                                ...
# 6111   1050219    1050201  2nd T20I:Pakistan v West Indies at Dubai (DSC)...
# 6112   1050221    1050201  3rd T20I:Pakistan v West Indies at Abu Dhabi- ...
# 6407   1077947    1077945  1st T20I:West Indies v Pakistan at Bridgetown-...
# 6408   1077948    1077945  2nd T20I:West Indies v Pakistan at Port of Spa...
# 6410   1085496    1077945  4th  T20I:West Indies v Pakistan at Port of Sp...
#
# ...

# %%
T20matches_pd[(T20matches_pd["winner"] == "Pakistan") & (T20matches_pd["home"] == "Pakistan")]
# Out:
#       match_id  series_id                                      match_details  \
# 750     306986     306979  1st Match:Pakistan v Uganda at Nairobi (Gym)- ...
# 758     287855     286109  3rd Match, Group D:Pakistan v Scotland at Durb...
# 771     287868     286109  16th Match, Group F:Pakistan v Sri Lanka at Jo...
# 854     343764     343758  Only T20I:Pakistan v Bangladesh at Karachi- Ap...
# 1089    361656     361644  4th Match:Pakistan v Sri Lanka at King City (N...
# 1090    361657     361644  5th Match:Pakistan v Zimbabwe at King City (NW...
# 1312    356015     335113  1st Semi-Final:Pakistan v South Africa at Nott...
# 1314    356017     335113  Final:Pakistan v Sri Lanka at Lord's- Jun 21, ...
# 1775    412697     412671  21st Match, Group E:Pakistan v South Africa at...
# 2534    530432     530423  Only T20I:Pakistan v Sri Lanka at Abu Dhabi- N...
# 3220    533286     531597  15th Match, Group 2:Pakistan v South Africa at...
# ...

# %%
##out of 69 matches pakistan won 19 matches in the home country.

# %%
I want the score column when pakistan played the matches

# %%
((T20matches_pd["home"]=="Pakistan") | (T20matches_pd["away"]=="Pakistan")).sum()
# Out:
# 116

# %%
(T20matches_pd["home"]=="Pakistan").sum()
# Out:
# 27

# %%
# pakistan played 116 matches in different series and won 69 matches and out of which it won 27 matches in home country 
#and won 19 matches. Now i want the total score card of the matches pakistan played.

# %%
T20matches_pd.loc[(T20matches_pd["home"]=="Pakistan") | (T20matches_pd["away"]=="Pakistan")]["scores"]
# Out:
# 480     England 144/7 (20/20 ov); Pakistan 148/5 (17.5...
# 526     Pakistan 129/8 (20/20 ov); South Africa 132/0 ...
# 750     Pakistan 226/3 (20/20 ov); Uganda 78/7 (20/20 ov)
# 753     Pakistan 191/7 (20/20 ov); Bangladesh 161/7 (2...
# 755       Kenya 92 (19.4/20 ov); Pakistan 93/2 (14/20 ov)
#                               ...
# 6112    West Indies 103/5 (20/20 ov); Pakistan 108/2 (...
# 6407    West Indies 111/8 (20/20 ov); Pakistan 115/4 (...
# 6408    Pakistan 132 (20/20 ov); West Indies 129/8 (20...
# 6409    Pakistan 137/8 (20/20 ov); West Indies 138/3 (...
# 6410    West Indies 124/8 (20/20 ov); Pakistan 127/3 (...
# Name: scores, Length: 116, dtype: object

# %%
T20matches_pd["innings1"].value_counts().sort_values(ascending=False).head(60)
# Out:
# innings1
# Surrey                         98
# Chennai Super Kings            91
# Mumbai Indians                 90
# Leicestershire                 89
# Hampshire                      88
# Lancashire                     84
# Kent                           80
# Northamptonshire               80
# Somerset                       79
# Yorkshire                      75
# Nottinghamshire                74
# Derbyshire                     71
# Sussex                         70
# Kings XI Punjab                70
# Middlesex                      69
# Warwickshire                   69
# Royal Challengers Bangalore    69
# Worcestershire                 68
# Kolkata Knight Riders          68
# Essex                          66
# Glamorgan                      66
# Cape Cobras                    65
# Durham                         65
# Delhi Daredevils               62
# Gloucestershire                62
# Dolphins                       60
# Pakistan                       59
# ...

# %% [markdown]
# # pakistan palyed 59 matches as first inings out of 116 and 56 as second inning

# %%
T20matches_pd["innings2"].value_counts().sort_values(ascending=False).head(60)
# Out:
# innings2
# Somerset                       87
# Royal Challengers Bangalore    86
# Essex                          86
# Sussex                         83
# Warwickshire                   82
# Middlesex                      81
# Kolkata Knight Riders          80
# Gloucestershire                79
# Delhi Daredevils               78
# Kent                           74
# Yorkshire                      73
# Durham                         73
# Mumbai Indians                 73
# Hampshire                      73
# Nottinghamshire                71
# Glamorgan                      71
# Kings XI Punjab                70
# Lancashire                     69
# Northamptonshire               69
# Worcestershire                 69
# Rajasthan Royals               67
# Titans                         65
# Derbyshire                     65
# Lions                          64
# Chennai Super Kings            64
# Warriors                       63
# Leicestershire                 61
# ...

# %%
((T20matches_pd["innings1"] == "") & ((T20matches_pd["home"] == "Pakistan") | (T20matches_pd["away"] == "Pakistan"))).sum()
# Out:
# 0

# %%
T20matches_pd[(T20matches_pd["result"] == "Match abandoned without a ball bowled") & ((T20matches_pd["home"] == "Pakistan") | (T20matches_pd["away"] == "Pakistan"))]
# Out:
#       match_id  series_id                                      match_details  \
# 3481    567366     567347  1st T20I:South Africa v Pakistan at Durban- Ma...
#
#                                      result scores        date   venue  \
# 3481  Match abandoned without a ball bowled    NaN  01/03/2013  Durban
#
#          round          home      away  ... innings1_wickets  \
# 3481  1st T20I  South Africa  Pakistan  ...              NaN
#
#       innings1_overs_batted  innings1_overs  innings2 innings2_runs  \
# 3481                    NaN             NaN       NaN           NaN
#
#       innings2_wickets  innings2_overs_batted  innings2_overs  D/L_method  \
# 3481               NaN                    NaN             NaN         NaN
#
#      target
# 3481    NaN
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Now we reach to point that pakistan played 116 matches out of 115 matches were valid and one match were cancelled due to rain

# %%
pakistani_matches=T20matches_pd[(T20matches_pd["home"]=="Pakistan") | (T20matches_pd["away"]=="Pakistan")]

# %%
((pakistani_matches["home"]!="Pakistan")  | (pakistani_matches["away"]!="Pakistan")).
# Out:
# 116
